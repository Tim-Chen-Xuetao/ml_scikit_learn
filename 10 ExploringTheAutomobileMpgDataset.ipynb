# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime

# %%
automobile_df = pd.read_csv('datasets/auto-mpg.csv')
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 206  26.5          4         140.0         72    2565          13.6
# 45   18.0          6         258.0        110    2962          13.5
# 268  27.2          4         119.0         97    2300          14.7
# 13   14.0          8         455.0        225    3086          10.0
# 384  32.0          4          91.0         67    1965          15.7
#
#      model year  origin                    car name
# 206          76       1                  ford pinto
# 45           71       1  amc hornet sportabout (sw)
# 268          78       3                  datsun 510
# 13           70       1     buick estate wagon (sw)
# 384          82       3          honda civic (auto)

# %%
automobile_df.shape
# Out:
# (398, 9)

# %%
automobile_df = automobile_df.replace('?', np.nan)

# %%
automobile_df = automobile_df.dropna()

# %%
automobile_df.shape
# Out:
# (392, 9)

# %%
automobile_df.drop(['origin', 'car name'], axis=1, inplace=True)

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 21   24.0          4         107.0         90    2430          14.5
# 278  31.5          4          89.0         71    1990          14.9
# 348  37.7          4          89.0         62    2050          17.3
# 111  18.0          3          70.0         90    2124          13.5
# 58   25.0          4          97.5         80    2126          17.0
#
#      model year
# 21           70
# 278          78
# 348          81
# 111          73
# 58           72

# %%
t=automobile_df['model year'].astype(str)
t
# Out:
# 0      70
# 1      70
# 2      70
# 3      70
# 4      70
#        ..
# 393    82
# 394    82
# 395    82
# 396    82
# 397    82
# Name: model year, Length: 392, dtype: object

# %%
automobile_df['model year'] = '19' + automobile_df['model year'].astype(str)

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration model year
# 353  33.0          4         105.0         74    2190          14.2       1981
# 161  16.0          6         250.0        105    3897          18.5       1975
# 332  29.8          4          89.0         62    1845          15.3       1980
# 60   20.0          4         140.0         90    2408          19.5       1972
# 210  19.0          6         156.0        108    2930          15.5       1976

# %%
automobile_df['age'] = datetime.datetime.now().year - pd.to_numeric(automobile_df['model year'])

# %%
automobile_df.drop(['model year'], axis=1, inplace=True)
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  age
# 324  40.8          4          85.0         65    2110          19.2   42
# 220  33.5          4          85.0         70    1945          16.8   45
# 379  36.0          4          98.0         70    2125          17.3   40
# 314  26.4          4         140.0         88    2870          18.1   42
# 295  35.7          4          98.0         80    1915          14.4   43

# %%
automobile_df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# age               int64
# dtype: object

# %%
automobile_df['horsepower'] = pd.to_numeric(automobile_df['horsepower'], errors='coerce')

# %%
automobile_df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration         age
# count    392.000000  392.000000
# mean      15.541327   46.020408
# std        2.758864    3.683737
# min        8.000000   40.000000
# 25%       13.775000   43.000000
# 50%       15.500000   46.000000
# 75%       17.025000   49.000000
# max       24.800000   52.000000

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(automobile_df['age'], automobile_df['mpg'])

plt.xlabel('Age')
plt.ylabel('Mile per gallon')
# Out:
# Text(0, 0.5, 'Mile per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(automobile_df['acceleration'], automobile_df['mpg'])

plt.xlabel('Acceleration')
plt.ylabel('Mile per gallon')
# Out:
# Text(0, 0.5, 'Mile per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(automobile_df['weight'], automobile_df['mpg'])

plt.xlabel('Weight')
plt.ylabel('Mile per gallon')
# Out:
# Text(0, 0.5, 'Mile per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(automobile_df['displacement'], automobile_df['mpg'])

plt.xlabel('Displacement')
plt.ylabel('Mile per gallon')
# Out:
# Text(0, 0.5, 'Mile per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(automobile_df['horsepower'], automobile_df['mpg'])

plt.xlabel('Horsepower')
plt.ylabel('Mile per gallon')
# Out:
# Text(0, 0.5, 'Mile per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.scatter(automobile_df['cylinders'], automobile_df['mpg'])

plt.xlabel('Cylinders')
plt.ylabel('Mile per gallon')
# Out:
# Text(0, 0.5, 'Mile per gallon')

# %%
automobile_corr = automobile_df.corr()
automobile_corr
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# age          -0.580541   0.345647      0.369855    0.416361  0.309120
#
#               acceleration       age
# mpg               0.423329 -0.580541
# cylinders        -0.504683  0.345647
# displacement     -0.543800  0.369855
# horsepower       -0.689196  0.416361
# weight           -0.416839  0.309120
# acceleration      1.000000 -0.290316
# age              -0.290316  1.000000

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(automobile_corr, annot=True)
# Out:
# <AxesSubplot: >

# %%
automobile_df = automobile_df.sample(frac=1).reset_index(drop=True)
automobile_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 0  17.0          6         163.0         125    3140          13.6   44
# 1  40.8          4          85.0          65    2110          19.2   42
# 2  36.1          4          91.0          60    1800          16.4   44
# 3  17.0          8         260.0         110    4060          19.0   45
# 4  13.0          8         318.0         150    3755          14.0   46

# %%
automobile_df.to_csv('datasets/auto-mpg-processed.csv', index=False)

# %%
# !ls datasets
# Out:
# auto-mpg.csv		 housing.csv		titanic_train.csv
# auto-mpg-processed.csv	 titanic_processed.csv
# fashion-mnist_train.csv  titanic_test.csv
